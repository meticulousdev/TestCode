# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# plt.rcParams['font.family'] = 'Times New Roman'
# plt.rcParams.update({'mathtext.default':  'default'})

plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

plt.rcParams.update({'font.size': 12})

# %%
data_columns = ['data01', 'data02', 'data03', 'data04', 'data05']

data_example = pd.DataFrame([[i, i * 2, i * i, np.sqrt(i), 1/(i+1)] for i in range(100)], 
                            index=None, 
                            columns=data_columns)
print(data_example)
# Out:
#     data01  data02  data03    data04    data05
# 0        0       0       0  0.000000  1.000000
# 1        1       2       1  1.000000  0.500000
# 2        2       4       4  1.414214  0.333333
# 3        3       6       9  1.732051  0.250000
# 4        4       8      16  2.000000  0.200000
# ..     ...     ...     ...       ...       ...
# 95      95     190    9025  9.746794  0.010417
# 96      96     192    9216  9.797959  0.010309
# 97      97     194    9409  9.848858  0.010204
# 98      98     196    9604  9.899495  0.010101
# 99      99     198    9801  9.949874  0.010000
#
# [100 rows x 5 columns]

# %%
mask = np.triu(np.ones_like(data_example.corr(), dtype=bool))
sns.heatmap(data_example.corr(), vmin=-1, vmax=1, mask=mask, annot=True)
plt.show()
